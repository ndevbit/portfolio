# %% [markdown]
# ---
# layout: post
# title: UESL 3.1 Homework
# author: ndevbit
# permalink: /homework/3-1/
# ---

# %% [markdown]
# ---
# ## Popcorn

# %%
game_title = "UESL Star Trail"
level_one_stars = 10
level_two_stars = 20
level_three_stars = 15
total_stars = level_one_stars + level_two_stars + level_three_stars
print(game_title)
print(total_stars)
level_two_stars = level_two_stars + 0 # The bonus? (previously 5)
print(total_stars)
total_stars = level_one_stars + level_two_stars + level_three_stars
print(total_stars)

# %% [markdown]
# ---
# ## Popcorn Hack Checkpoint Challenge

# %%
stars = 8
checkpoint_stars = stars
stars = stars + 4
print(stars)
print(checkpoint_stars)

# Predictions
# stars: 12
# checkpoint_stars: 8

# %% [markdown]
# ### Prediction:
#
# Predictions
# - stars: 12
# - checkpoint_stars: 8
#
# ### Actual output:
# - 12
# - 8

# %% [markdown]
# ---
# ## MCQ
# 1. B
# 2. A
# 3. A
# 4. B

# %% [markdown]
# ---
# ## Homework

# %%
game_name = "COOL_GAME"

stars_lvl1 = 12
stars_lvl2 = 18
stars_lvl3 = 10

reduced_motion = False

# Store total
total_stored = stars_lvl1 + stars_lvl2 + stars_lvl3

# Print values
print(f"Game name: {game_name}")
print(f"Reduced motion: {reduced_motion}")
print(f"Total: {total_stored}")

# Add bonus
stars_lvl2 += 5

print(total_stored)

# Recalculate total
total_stored = stars_lvl1 + stars_lvl2 + stars_lvl3

print(total_stored)

# Predictions:
# Kind of fabricated since I saw the numbers on the lesson
# total_stored: 40
# total_stored after adding the bonus: 40 (45 if total_stored was recalculated)
# 
# Bonus now 0
# total_stored: 40
# total_stored after adding the bonus: 40
# Out:
# Game name: COOL_GAME
# Reduced motion: False
# Total: 40
# 40
# 45

# %% [markdown]
# ---
# ## Tests

# %% [markdown]
# ### Prediction:
#
# Predictions (kind of fabricated, I ran the code previously and saw the output)
# - Original total: 45
# - Stored total: 45
# - Recalculated total: (Stored total + 5) = 50
#
# ### Actual output:
#
# UESL Star Trail
# - 45
# - 45
# - 50

# %% [markdown]
# ### Predictions:
# Kind of fabricated since I saw the numbers on the lesson
# - total_stored: 40
# - total_stored after adding the bonus: 40 (45 if total_stored was recalculated)
#
# Bonus now 0:
# - total_stored: 40
# - total_stored after adding the bonus: 40
#
# ### Actual ouptut:
# - Game name: COOL_GAME
# - Reduced motion: False
# - Total: 40
# - 40
# - 45

# %% [markdown]
# ---
# ## Design Thinking

# %% [markdown]
# Hypothetically speaking, since I find it hard to tie these ideas back into the assignment
#
# ### Player need
# Obtain the stars (in game)
# Low latency, like a smooth consistent 60fps (outside the game)
#
# ### My goal
# To make the game easy to understand
#
# ### Setting/representation
# - Possibly the naming scheme of the variables in the code (I like underscores and capitals)
#
# - I think a list would be better and more extensible for storing star counts in levels
#
# ### Prototype
# The python script I made for the homework meets all the main points of the assignment
#
# ### Test/revision
# I believe I misunderstood the assignment the first time, and that the addition of 5 to the second star count as the bonus was a vital component in understanding the code
#
# ### Reduced motion being a player choice
# Reduced motion should be a player choice because it allows the user to play the game in a way that they prefer, allowinng a the game to be more dynamic and giving the player more freedom over their experience
