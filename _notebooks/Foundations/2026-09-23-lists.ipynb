# %% [markdown]
# ---
# layout: post
# title: 3.10 Lists
# permalink: /csp/big-idea-3/lists/
# toc: true
# comments: false
# ---

# %% [markdown]
# ## Lists

# %% [markdown]
# Popcorn Hack #1

# %%
# CODE_RUNNER

#Convert the above CollegeBoard Psuedocode into Python code and run it. 
#Predict the output of each print statement before running the code. Add your prediction as a comment next to each print statement.

foods = ["pizza", "sushi", "tacos", "ramen"]

print(foods[0]) # Should print "pizza"
print(foods[-1]) # Should print "ramen"
print(len(foods)) # Should print "4"
# print(foods[4]) # Should error

# Fix for the "print(foods[4])"
print(foods[3]) # foods[3] is in the list, just at the end of the list
# Out:
# pizza
# ramen
# 4
# ramen

# %% [markdown]
# ---
# Popcorn Hack #2

# %%
# CODE_RUNNER

#Now try it yourself! Write a for loop that calculates the sum of all the numbers in the list and prints it out.
#Calculate the average of the numbers in the list using the value you calculated for the sum and the length of the list and print it out.

numbers = [7, 6, 8, 5, 7, 9]

sum = 0
for n in numbers:
    sum += n
    
print(f"sum: {sum}")

average = round(sum / len(numbers), 2)

print(f"average: {average}")

# %% [markdown]
# ---
# Popcorn Hack #3

# %%
# CODE_RUNNER

seasons = ["winter", "summer", "fall", "summer", "spring", "summer", "fall"]   # use real class data

frequency = {}
for season in seasons:
    if season in frequency:
        frequency[season] += 1
    else:
        frequency[season] = 1
        
# 1. Build a list of seasons with 2 or more votes
# TODO: create an empty list called popular, loop over frequency,
# and append any season whose count is 2 or more
popular = []
for key in frequency:
    if frequency[key] >= 2:
        popular.append(key)
        
# 2. Print that list
# TODO: print(popular)
print(popular)
# Out:
# ['summer', 'fall']

# %% [markdown]
# ---
# Homework

# %%
# CODE_RUNNER

votes = ["chips", "cookies", "chips", "fruit", "cookies", "chips",
         "pretzels", "cookies", "chips", "fruit", "chips", "cookies"]

prices = [2, 3, 2, 4, 3, 2, 1, 3, 2, 4, 2, 3]

# LESSON 1 - indexing
# 1. Print how many votes were cast
# 2. Print the last vote using indexing
print(len(votes))
print(votes[-1])

# LESSON 2 - sum and average
# 3. Use a loop to total prices (do NOT use sum())
# 4. Print "Total: <total>" and "Average: <average>" as integers using the int() function
#ex: print(int(total)) would print the integer value of total
sum = 0
for price in prices:
    sum += price
    
average = round(sum / len(prices), 2)
    
print(f"Total: {sum}")
print(f"Average {int(average)}")

# LESSON 3 - count and filter
# 5. Build a frequency dictionary of votes and print it
# 6. Build a list of snacks with 3 or more votes and print it
frequency = {}

for vote in votes:
    if vote in frequency: # Already in frequency? Increment sightings count
        frequency[vote] += 1
    else: # Not in frequency yet, register it as 1
        frequency[vote] = 1
        
popular = []

for snack in frequency:
    if frequency[snack] >= 3:
        popular.append(snack)
        
print(votes)
        
print(popular)
# Out:
# 12
# cookies
# Total: 31
# Average 2
# ['chips', 'cookies', 'chips', 'fruit', 'cookies', 'chips', 'pretzels', 'cookies', 'chips', 'fruit', 'chips', 'cookies']
# ['chips', 'cookies']
