# %% [markdown]
# ---
# layout: post
# categories: [Python, Strings]
# lesson_language: Python
# lesson_topic: Strings
# lesson_part: interactive
# lesson_type: lesson
# title: 3.4 Strings HW HW
# permalink: /csp/python/strings/hw
# Authors: Noah Dabrowski
# ---

# %% [markdown]
# ---
# Popcorn hacks 1-3 (top to bottom, top is 1st, bottom is 3rd)

# %% [markdown]
# ---
# Popcorn Hack #1

# %%
# CODE_RUNNER:
raw = "   Agent-Zero says: the drop is at MIDNIGHT!!!  "

# My work
midnight = raw[35:43]
print(midnight)
# Out:
# MIDNIGHT

# %% [markdown]
# ---
# Popcorn Hack #2

# %%
# CODE_RUNNER:
parts = ["ALPHA", "BRAVO", "CHARLIE"]
print("-".join(parts))     # glues a LIST into ONE string, with "-" between pieces

# My work
result = (" ".join(parts)).lower()

print("\nMy work:")
print(result)
print("\n")
# Out:
# ALPHA-BRAVO-CHARLIE
#
# My work:
# alpha bravo charlie

# %% [markdown]
# ---
# Popcorn Hack #3

# %%
# CODE_RUNNER:
raw_transmission = "  2026-09-15,GHOST,THE-EAGLE-LANDS-AT-DAWN,87  "

stripped = raw_transmission.strip()
print(stripped)

fields = stripped.split(",")
print("fields:", fields)

date = fields[0]
agent = fields[1]
message_code = fields[2]
confidence_str = fields[3]
print(f"Date: {date} | Agent: {agent} | Message code: {message_code} | Confidence: {confidence_str}")

year_check = date[0:4]
print("Year check:", year_check)
print("2026 Year Check:", year_check == "2026")

message = message_code.replace("-", " ")

found_dawn = "dawn" in message.lower()
print("Found \'dawn\':", found_dawn)

markdown_row = f"| {date} | {agent} | {message} | {confidence_str} |"
print("Markdown row:", markdown_row)

json_line = "{" + f"""
    \"date\": \"{date}\"
    \"agent\": \"{agent}\"
    \"message\": \"{message}\"
    \"confidence\": \"{confidence_str}\"
    \"found_dawn lowercase\": \"{str(found_dawn).lower()}
""" + "}"
print("JSON line:", json_line)
# Out:
# 2026-09-15,GHOST,THE-EAGLE-LANDS-AT-DAWN,87
# fields: ['2026-09-15', 'GHOST', 'THE-EAGLE-LANDS-AT-DAWN', '87']
# Date: 2026-09-15 | Agent: GHOST | Message code: THE-EAGLE-LANDS-AT-DAWN | Confidence: 87
# Year check: 2026
# 2026 Year Check: True
# Found 'dawn': True
# Markdown row: | 2026-09-15 | GHOST | THE EAGLE LANDS AT DAWN | 87 |
# JSON line: {
#     "date": "2026-09-15"
#     "agent": "GHOST"
#     "message": "THE EAGLE LANDS AT DAWN"
#     "confidence": "87"
#     "found_dawn lowercase": "true
# }

# %% [markdown]
# ---
# Homework

# %%
# CODE_RUNNER:
raw_transmission = "  2026-09-15,GHOST,THE-EAGLE-LANDS-AT-DAWN,87  "

stripped = raw_transmission.strip()
fields = stripped.split(",")

print(fields)

date = fields[0]
agent = fields[1]
message_code = fields[2]
confidence_str = fields[3]

print(f"Date: {date} | Agent: {agent} | Message Code: {message_code} | Confidence: {confidence_str}")

year_check = date[0:4]
print("Year check:", year_check)
print("2026 Year Check:", year_check == "2026")

message = message_code.replace("-", " ")

found_dawn = "dawn" in message
print("Found Dawn:", found_dawn)

markdown_row = f"{date} | {agent} | {message} | {confidence_str}"
print("Markdown row:", markdown_row)

json_line = "{" + f"""
    \"date\": \"{date}\"
    \"agent\": \"{agent}\"
    \"message\": \"{message}\"
    \"confidence\": \"{confidence_str}\"
    \"contains_dawn lowercase\": \"{str(found_dawn).lower()}\"
""" + "}"
print("JSON:", json_line)
# Out:
# ['2026-09-15', 'GHOST', 'THE-EAGLE-LANDS-AT-DAWN', '87']
# Date: 2026-09-15 | Agent: GHOST | Message Code: THE-EAGLE-LANDS-AT-DAWN | Confidence: 87
# Year check: 2026
# 2026 Year Check: True
# Found Dawn: False
# Markdown row: 2026-09-15 | GHOST | THE EAGLE LANDS AT DAWN | 87
# JSON: {
#     "date": "2026-09-15"
#     "agent": "GHOST"
#     "message": "THE EAGLE LANDS AT DAWN"
#     "confidence": "87"
#     "contains_dawn lowercase": "false"
# }
