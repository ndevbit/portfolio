# %% [markdown]
# ---
# layout: post
# title: UESL 3.2 Homework
# author: Noah Dabrowski
# permalink: /homework/3-2/
# ---

# %% [markdown]
# ---
# ## Popcorn

# %% [markdown]
# ```python
# # Your UESL prototype goes here.
# level_stars = [10, 20, 15]
# print(level_stars[0])
# print(level_stars[1])
# print(len(level_stars))
# ```
# Prediction:
# 10
# 20
# 15
# Actual output:
# 10
# 20
# 3
#
# ```python
# # Your UESL prototype goes here.
# level_stars = [6, 9, 12]
# level_stars[1] = level_stars[1] + 3
# level_stars.append(5)
# print(level_stars)
# print(len(level_stars))
# ```
# Prediction:
# [6, 9, 12]
# 3
# Actual output:
# [6, 12, 12, 5]
# 4
#
# ```python
# # Your UESL prototype goes here.
# level_stars = [10, 20, 15]
# total_stars = 0
# for stars in level_stars:
#     total_stars = total_stars + stars
# print(len(level_stars))
# print(total_stars)
# ```
# Prediction:
# 3
# 45
# Actual output:
# 3
# 45

# %% [markdown]
# ---
# ## MCQ
#
# 1. B
# 2. A
# 3. C
# 4. B
#
# Score: 4/4

# %% [markdown]
# ---
# ## Homework

# %%
level_stars = [12, 18, 10]

level_stars[2] += 5

level_stars.append(7)

# Copied from "example C"
total_stars = 0
for stars in level_stars:
    total_stars = total_stars + stars
print(len(level_stars))
print(total_stars)

# %% [markdown]
# ---
# ## Tests

# %%
level_stars = []

# Copied from "example C"
total_stars = 0
for stars in level_stars:
    total_stars = total_stars + stars
print(len(level_stars))
print(total_stars)
# Out:
# 0
# 0

# %%
level_count = 3

level_stars = [0, 0, 0] # len(level_stars) = level_count

level_names = ["sigma sands", "cool place", "awesome house"] # len(level_names) = level_count

# Copied and modifed from "example C"
total_stars = 0
index = 0
for stars in level_stars:
    print(f"Level \"{level_names[index]}\" star count: {stars}")
    total_stars = total_stars + stars
    index += 1
    
print(len(level_stars))
print(total_stars)

# Complexity Explanation:
# 
# The "level_count" variable holds the length of "level_stars" and "level_names" lists
# Keeping the "level_stars" and "level_names" lists the same length is important because the level name and the level star count are supposed to grouped together
# However they are stored separately in the "level_stars" and "level_names" lists
# The loop copied from "example C" amasses a "total_stars" variable, which is the sum of all the elements in the "level_stars" list
# The index variable allows both the "level_stars" and "level_names" lists to be indexed and their elements treated as one object (the level's star count and the level's name)
# The print statements simply log the program's workings
# Out:
# Level "sigma sands" star count: 0
# Level "cool place" star count: 0
# Level "awesome house" star count: 0
# 3
# 0

# %% [markdown]
# A list prevents modifications to hundreds of variables having only one name to handle all of the data.

# %% [markdown]
# ---
# ## Design Thinking

# %% [markdown]
# design-thinking note:
# - The player may need to store their inventory in a list, to prevent hardcoded slots
# - The player may want multiple settings configurations for their gameplay, so a list storing these configurations would be very helpful
#
# - A goal I have (hypothetically) is to stored the elements (stars, enemies, etc) in a level using a list
#
# - A representation I consider is having each element in a level have an "id" variable in them, telling the game how to interpret the element
#
# - I notice in the prototype I put together for the homework part of this assignment goes from using hardcoded variables for the level star counts (stars_level1, stars_level2, etc.) to using a list for the level star counts.
#
# - A test I performed was when the assignment instructed me to change the list length to 0, by changing the definition of "level_stars" to "[]"
#
# - Clear level names I included are in the second test (the one with the "level_count" variable)
